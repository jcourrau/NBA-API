# %% [markdown]
# # NBA Today's games score importer

# %% [markdown]
# ## Import Libraries

# %%
# %pip install pandas nba_api pymongo python-dotenv dnspython
# Out:
# Requirement already satisfied: pandas in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (3.0.0)
# Requirement already satisfied: nba_api in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (1.11.4)
# Requirement already satisfied: pymongo in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (4.16.0)
# Requirement already satisfied: python-dotenv in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (1.2.1)
# Requirement already satisfied: dnspython in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (2.8.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (from nba_api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2026.1.4)
# Requirement already satisfied: six>=1.5 in c:\users\jason\onedrive\education\0- ulead ciencia de datos\materias\6 cuatrimestre\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from datetime import date, timedelta
from nba_api.stats.endpoints import scoreboardv3
import os
from dotenv import load_dotenv
from pymongo import MongoClient, UpdateOne

# %% [markdown]
# # NBA game Scores

# %% [markdown]
# ### Get scores for Yesterday
# Yesterday's scores are obtained in order to ensure complete scores.
#
# > Today's live scores can be obtained using `today_date`

# %%
today_date = date.today()
yesterday_date = date.today() - timedelta(days=1)

scoreboard = scoreboardv3.ScoreboardV3(
    league_id="00",
    game_date= yesterday_date
)

game_header = scoreboard.game_header.get_data_frame()
line_score = scoreboard.line_score.get_data_frame()

# Preview a game
example_game_id = line_score['gameId'].iloc[0]
display(game_header[game_header['gameId'] == example_game_id])
display(line_score[line_score['gameId'] == example_game_id])
# Out:
#        gameId         gameCode  gameStatus gameStatusText  period gameClock  \
# 0  0022500811  20260221/ORLPHX           3      Final/OT2       6
#
#             gameTimeUTC                gameEt  regulationPeriods  \
# 0  2026-02-21T22:00:00Z  2026-02-21T17:00:00Z                  4
#
#   seriesGameNumber gameLabel gameSubLabel seriesText  ifNecessary  \
# 0                                                           False
#
#   seriesConference poRoundDesc gameSubtype  isNeutral
# 0                                               False
#        gameId      teamId teamCity teamName teamTricode teamSlug  wins  \
# 0  0022500811  1610612756  Phoenix     Suns         PHX     suns    33
# 1  0022500811  1610612753  Orlando    Magic         ORL    magic    29
#
#    losses  score  seed inBonus  timeoutsRemaining
# 0      24    113     0    None                  0
# 1      26    110     0    None                  0

# %% [markdown]
# ## Build Game-Level NBA Results Table
#
# This code transforms raw NBA scoreboard data into a clean, game-level dataset.

# %% [markdown]
# ### 1. Identify Home and Away Teams
# Using the `gameCode` from `game_header`, the script extracts:
# - Away team tricode (first 3 letters)
# - Home team tricode (last 3 letters)
#
# Each row in `line_score` is then labeled as either `home` or `away`.
# > Example: 20260222/CLEOKC means away CLE, home OKC

# %%
ls = line_score.copy()
gh = game_header.copy()

ls["home_tricode"] = ls["gameId"].map(gh.set_index("gameId")["gameCode"]).str.split("/").str[1].str[-3:]
ls["away_tricode"] = ls["gameId"].map(gh.set_index("gameId")["gameCode"]).str.split("/").str[1].str[:3]

ls["is_home"] = ls["teamTricode"] == ls["home_tricode"]
ls["side"] = ls["is_home"].map({True: "home", False: "away"})

# %% [markdown]
# ### 2. Select Relevant Fields
# From the enriched `line_score`, only the necessary columns are kept:
# - Game ID
# - Team info
# - Wins / Losses
# - Score
# - Home/Away side

# %%
ls_small = ls[[
    "gameId","side",
    "teamId","teamCity","teamName","teamTricode",
    "wins","losses","score"
]]

# %% [markdown]
# ### 3. Reshape to One Row per Game
# The dataset is pivoted from:
# - Two rows per game (one per team)
#
# Into:
# - One row per game
# - Separate columns for home and away statistics
#
# Example:
# - `teamName_home`
# - `teamName_away`
# - `score_home`
# - `score_away`

# %%
game_level_df = (
    ls_small
    .set_index(["gameId","side"])
    .unstack("side")
)

# Flatten columns like ("score","home") -> "home_score"
game_level_df.columns = [f"{col}_{side}" for col, side in game_level_df.columns]
game_level_df = game_level_df.reset_index()

# %% [markdown]
# ### 4. Add Game Metadata
# The reshaped table is merged with `game_header` to include:
# - Game status
# - Period
# - Game clock
# - Game time

# %%
game_scores_df = game_level_df.merge(
    gh[["gameId","gameStatus","gameStatusText","period","gameClock","gameTimeUTC","gameEt"]],
    on="gameId",
    how="left"
)

# %% [markdown]
# ### Output table
# A clean, structured DataFrame where:
# - Each row represents one NBA game
# - Home and away team statistics are clearly separated
# - Game status information is included

# %%
print(game_scores_df.columns)
preview_df = game_scores_df[[
    "gameId",'teamName_away','teamName_home',
    "score_away","score_home",
    "wins_away","wins_home",
    "losses_away","losses_home"
]]
preview_df.head()
# Out:
# Index(['gameId', 'teamId_away', 'teamId_home', 'teamCity_away',
#        'teamCity_home', 'teamName_away', 'teamName_home', 'teamTricode_away',
#        'teamTricode_home', 'wins_away', 'wins_home', 'losses_away',
#        'losses_home', 'score_away', 'score_home', 'gameStatus',
#        'gameStatusText', 'period', 'gameClock', 'gameTimeUTC', 'gameEt'],
#       dtype='str')
#        gameId teamName_away teamName_home  score_away  score_home  wins_away  \
# 0  0022500811         Magic          Suns         110         113         29
# 1  0022500812         76ers      Pelicans         111         126         30
# 2  0022500813     Grizzlies          Heat         120         136         21
# 3  0022500814       Pistons         Bulls         126         110         42
# 4  0022500815         Kings         Spurs         122         139         12
#
#    wins_home  losses_away  losses_home
# 0         33           26           24
# 1         16           26           42
# 2         31           34           27
# 3         24           13           33
# 4         40           46           16

# %% [markdown]
# # Upload to Mongo

# %% [markdown]
# ### Connect to Mongo

# %%
load_dotenv()

MONGO_URI = os.getenv("MONGO_URI")
MONGO_DB = os.getenv("MONGO_DB", "nba")
MONGO_COLLECTION = os.getenv("MONGO_COLLECTION", "scoreboard_games")

if not MONGO_URI:
    raise ValueError("Falta MONGO_URI en el archivo .env")

client = MongoClient(MONGO_URI)
col = client[MONGO_DB][MONGO_COLLECTION]

# %% [markdown]
# ### Insert scores using upsert
# * Uses `gameID`as key for unique rows.
# * It only uploads new games.
# * Updates previously added games if new values are found.

# %%
df_out = game_scores_df.copy()
records = df_out.to_dict("records")

ops = []
for r in records:
    key = {"gameId": r["gameId"]}  # game key as unique identifier
    ops.append(UpdateOne(key, {"$set": r}, upsert=True))

result = None
if ops:
    result = col.bulk_write(ops, ordered=False)
    result.bulk_api_result
    
    print("Load result:")
    print(f"New inserted: {result.upserted_count}")
    print(f"Modified existing: {result.modified_count}")
    print(f"Total processed: {len(ops)}")
else:
    print("No rows to update.")
# Out:
# Load result:
# New inserted: 0
# Modified existing: 0
# Total processed: 6
